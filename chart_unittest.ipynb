# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xaxis = range(100,2000,190)
results = [1000,
            999.7137533,
            922.1658701,
            37.6466903,
            0.0,
            0.0,
            1000,
            1000,
            1000,
            1000]
results
# Out:
# [1000, 999.7137533, 922.1658701, 37.6466903, 0.0, 0.0, 1000, 1000, 1000, 1000]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.axvline(1216, color='red')

plt.xlabel("Wavelength ("+u"\u212B"+")")
plt.plot(xaxis,results)
